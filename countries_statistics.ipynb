# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('countries-of-the-world.csv')
df.head(2)
# Out:
#         Country                               Region  Population  \
# 0  Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1      Albania   EASTERN EUROPE                          3581655
#
#    Area (sq. mi.) Pop. Density (per sq. mi.) Coastline (coast/area ratio)  \
# 0          647500                       48,0                         0,00
# 1           28748                      124,6                         1,26
#
#   Net migration Infant mortality (per 1000 births)  GDP ($ per capita)  \
# 0         23,06                             163,07               700.0
# 1         -4,93                              21,52              4500.0
#
#   Literacy (%) Phones (per 1000) Arable (%) Crops (%) Other (%) Climate  \
# 0         36,0               3,2      12,13      0,22     87,65       1
# 1         86,5              71,2      21,09      4,42     74,49       3
#
#   Birthrate Deathrate Agriculture Industry Service
# 0      46,6     20,34        0,38     0,24    0,38
# ...

# %% [markdown]
# ### Extracting GDP & phones
# - GDP is the value of all the goods and services produced in a year, expressed as dollars per person.
# - phones is a list of the number of mobile phones per 1,000 people in that country
# - percent_literate - the percent of each country's population that can read and write

# %%
gdp = df.loc[:,'GDP ($ per capita)']
phones = df.loc[:,'Phones (per 1000)'].str.replace(',', '.').astype(float)
percent_literate = df.loc[:,'Literacy (%)'].str.replace(',', '.').astype(float)
region = df.loc[:,'Region'].str.strip()

# %%
f, ax = plt.subplots(1,2, figsize=(16,8))
sns.scatterplot(x = gdp, y = phones, ax = ax[0])
sns.scatterplot(x = gdp, y = percent_literate, ax=ax[1])
plt.show()

# %% [markdown]
# Countries with a lower GDP do seem more likely to have a lower percent of the population that can read and write.

# %%
sns.countplot(y=region)

# %% [markdown]
# Sub-Saharan Africa contains the most countries in this list
